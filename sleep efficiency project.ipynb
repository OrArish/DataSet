# %% [markdown]
# ## sleep effiecincy

# %% [markdown]
# ## Uploading files

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime

# %%
url = "https://raw.githubusercontent.com/OrArish/DataSet/main/Sleep_Efficiency.csv"
sleep_df = pd.read_csv(url)
sleep_df.info()
sleep_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
# Fill missing values for numerical columns with the median of each column
sleep_df['Awakenings'].fillna(sleep_df['Awakenings'].median(), inplace=True)
sleep_df['Caffeine consumption'].fillna(sleep_df['Caffeine consumption'].median(), inplace=True)
sleep_df['Alcohol consumption'].fillna(sleep_df['Alcohol consumption'].median(), inplace=True)
sleep_df['Exercise frequency'].fillna(sleep_df['Exercise frequency'].median(), inplace=True)

# %%
fig, ax = plt.subplots (figsize=(15, 5),  ncols=10)
plt.subplots_adjust(wspace = 0.3)
sns.boxplot(data = sleep_df[['Age']], ax = ax[0])
sns.boxplot(data = sleep_df[['REM sleep percentage']], ax = ax[1])
sns.boxplot(data = sleep_df[['Sleep duration']], ax = ax[2])
sns.boxplot(data = sleep_df[['Sleep efficiency']], ax = ax[3])
sns.boxplot(data = sleep_df[['Deep sleep percentage']], ax = ax[4])
sns.boxplot(data = sleep_df[['Light sleep percentage']], ax = ax[5])
sns.boxplot(data = sleep_df[['Awakenings']], ax = ax[6])
sns.boxplot(data = sleep_df[['Caffeine consumption']], ax = ax[7])
sns.boxplot(data = sleep_df[['Alcohol consumption']], ax = ax[8])
sns.boxplot(data = sleep_df[['Exercise frequency']], ax = ax[9])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sleep_df["Smoking status"] = sleep_df["Smoking status"].replace({'Yes': 1, 'No' : 0})

# %%
sleep_df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
data = {sleep_df['Age'],sleep_df[['REM sleep percentage']],sleep_df[['Sleep duration']],sleep_df[['Sleep efficiency']],}
corr_matrix = sleep_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = {sleep_df['Age'],sleep_df[['REM sleep percentage']],sleep_df[['Sleep duration']],sleep_df[['Sleep efficiency']],}
#       2 corr_matrix = sleep_df.corr()
#       3 plt.figure(figsize=(10, 8))
#
# TypeError: unhashable type: 'Series'

# %%
# Convert 'Bedtime' and 'Wakeup time' to datetime
sleep_df['Bedtime'] = pd.to_datetime(sleep_df['Bedtime'])
sleep_df['Wakeup time'] = pd.to_datetime(sleep_df['Wakeup time'])

# Convert 'Smoking status' from 'Yes'/'No' to 1/0
sleep_df['Smoking status'] = sleep_df['Smoking status'].replace({'Yes': 1, 'No': 0})

# Display data types to ensure proper conversion
sleep_df.dtypes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Summary statistics
summary_stats = sleep_df.describe()

# Plot distributions of key variables
plt.figure(figsize=(15, 10))
sns.histplot(sleep_df['Age'], kde=True)
plt.title('Distribution of Age')
plt.show()

plt.figure(figsize=(15, 10))
sns.histplot(sleep_df['Sleep duration'], kde=True)
plt.title('Distribution of Sleep Duration')
plt.show()

plt.figure(figsize=(15, 10))
sns.histplot(sleep_df['Sleep efficiency'], kde=True)
plt.title('Distribution of Sleep Efficiency')
plt.show()

# %%
# Check unique values in 'Exercise frequency' column
unique_exercise_values = sleep_df['Exercise frequency'].unique()
unique_exercise_values

# %%
# Convert 'Exercise frequency' to numeric, coercing errors
sleep_df['Exercise frequency'] = pd.to_numeric(sleep_df['Exercise frequency'], errors='coerce')

# Drop rows with NaN values in 'Exercise frequency' (if any)
sleep_df.dropna(subset=['Exercise frequency'], inplace=True)

# Plot the relationship between 'Exercise frequency' and 'Deep sleep percentage'
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Exercise frequency', y='Deep sleep percentage')
plt.title('Exercise Frequency vs. Deep Sleep Percentage')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Sleep duration', y='Sleep efficiency')
plt.title('Sleep Efficiency vs. Sleep Duration')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Caffeine consumption', y='Sleep efficiency')
plt.title('Impact of Caffeine Consumption on Sleep Efficiency')
plt.show()

# %%
# Impact of Alcohol Consumption on Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='Sleep efficiency')
plt.title('Impact of Alcohol Consumption on Sleep Efficiency')
plt.show()

# Impact of Alcohol Consumption on REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='REM sleep percentage')
plt.title('Impact of Alcohol Consumption on REM Sleep Percentage')
plt.show()

# Convert 'Gender' to numeric (0 for Female, 1 for Male)
sleep_df['Gender'] = sleep_df['Gender'].replace({'Female': 0, 'Male': 1})

# Gender Differences in Sleep Duration
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Gender', y='Sleep duration')
plt.title('Gender Differences in Sleep Duration')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# Gender Differences in Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Gender', y='Sleep efficiency')
plt.title('Gender Differences in Sleep Efficiency')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
# Effect of Smoking Status on Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Smoking status', y='Sleep efficiency')
plt.title('Effect of Smoking Status on Sleep Efficiency')
plt.show()

# Effect of Smoking Status on REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Smoking status', y='REM sleep percentage')
plt.title('Effect of Smoking Status on REM Sleep Percentage')
plt.show()

# %%
# Relationship between Age and Sleep Duration
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='Sleep duration')
plt.title('Relationship between Age and Sleep Duration')
plt.show()

# Relationship between Age and Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='Sleep efficiency')
plt.title('Relationship between Age and Sleep Efficiency')
plt.show()

# Relationship between Age and REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='REM sleep percentage')
plt.title('Relationship between Age and REM Sleep Percentage')
plt.show()

# %%
# Impact of Alcohol Consumption on Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='Sleep efficiency')
plt.title('Impact of Alcohol Consumption on Sleep Efficiency')
plt.show()

# Impact of Alcohol Consumption on REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='REM sleep percentage')
plt.title('Impact of Alcohol Consumption on REM Sleep Percentage')
plt.show()

# %%
# Impact of Alcohol Consumption on Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='Sleep efficiency')
plt.title('Impact of Alcohol Consumption on Sleep Efficiency')
plt.show()

# %%
# Impact of Alcohol Consumption on REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Alcohol consumption', y='REM sleep percentage')
plt.title('Impact of Alcohol Consumption on REM Sleep Percentage')
plt.show()

# %%
# Convert 'Gender' to numeric (0 for Female, 1 for Male)
sleep_df['Gender'] = sleep_df['Gender'].replace({'Female': 0, 'Male': 1})

# Gender Differences in Sleep Duration
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Gender', y='Sleep duration')
plt.title('Gender Differences in Sleep Duration')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# Gender Differences in Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.boxplot(data=sleep_df, x='Gender', y='Sleep efficiency')
plt.title('Gender Differences in Sleep Efficiency')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
# Relationship between Age and Sleep Duration
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='Sleep duration')
plt.title('Relationship between Age and Sleep Duration')
plt.show()

# Relationship between Age and Sleep Efficiency
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='Sleep efficiency')
plt.title('Relationship between Age and Sleep Efficiency')
plt.show()

# Relationship between Age and REM Sleep Percentage
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sleep_df, x='Age', y='REM sleep percentage')
plt.title('Relationship between Age and REM Sleep Percentage')
plt.show()

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a line plot to show the relationship between Caffeine consumption and Sleep efficiency
plt.figure(figsize=(12, 6))
sns.lineplot(x='Caffeine consumption', y='Sleep efficiency', data=sleep_df, marker='o')
plt.title('Line Plot of Caffeine Consumption and Sleep Efficiency')
plt.xlabel('Caffeine Consumption (mg)')
plt.ylabel('Sleep Efficiency')
plt.show()

# %%
# Create a scatter plot to show the relationship between Exercise frequency and Deep sleep percentage
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Exercise frequency', y='Deep sleep percentage', data=sleep_df)
plt.title('Scatter Plot of Exercise Frequency and Deep Sleep Percentage')
plt.xlabel('Exercise Frequency (times per week)')
plt.ylabel('Deep Sleep Percentage')
plt.show()

# Create a line plot to show the relationship between Exercise frequency and Deep sleep percentage
plt.figure(figsize=(12, 6))
sns.lineplot(x='Exercise frequency', y='Deep sleep percentage', data=sleep_df, marker='o')
plt.title('Line Plot of Exercise Frequency and Deep Sleep Percentage')
plt.xlabel('Exercise Frequency (times per week)')
plt.ylabel('Deep Sleep Percentage')
plt.show()

# %%
# Create a line plot to show the relationship between Alcohol consumption and Awakenings
plt.figure(figsize=(12, 6))
sns.lineplot(x='Alcohol consumption', y='Awakenings', data=sleep_df, marker='o')
plt.title('Line Plot of Alcohol Consumption and Awakenings')
plt.xlabel('Alcohol Consumption (units)')
plt.ylabel('Awakenings (times per night)')
plt.show()
